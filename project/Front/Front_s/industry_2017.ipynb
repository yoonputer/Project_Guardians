# %%
import pandas as pd

# %%
df = pd.read_csv('사업장별_온실가스_배출량∙에너지_사용량_(2017).CSV')
df.head(5)
# Out:
#    NO DPRTM_CHRG              CORP_NM  ... ENG_CNSM_BU_UNIT     VRFCT_AGNCY TST
# 0   1    산업통상자원부  (유)에스케이씨에보닉페록사이드코리아  ...                -       (재)한국품질재단   -
# 1   2      국토교통부              (유)호남고속  ...                -      (주)한국경영인증원   -
# 2   3    산업통상자원부              (주)HM금속  ...                -          한국표준협회   -
# 3   4    농림축산식품부             (주)MH에탄올  ...                -  (재)한국화학융합시험연구원   -
# 4   5    농림축산식품부               (주)MSC  ...                -       한국산업기술시험원   -
#
# [5 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NO                958 non-null    int64
#  1   DPRTM_CHRG        958 non-null    object
#  2   CORP_NM           958 non-null    object
#  3   ADDRESS           958 non-null    object
#  4   TRGT_YEAR         958 non-null    int64
#  5   DSGN_CLSF         958 non-null    object
#  6   DSGN_INDS         958 non-null    object
#  7   GHG_EMS           958 non-null    object
#  8   GHG_UNIT          958 non-null    object
#  9   GHG_EMS_BU        958 non-null    object
#  10  GHG_EMS_BU_UNIT   958 non-null    object
#  11  ENG_CNSM          958 non-null    object
#  12  ENG_UNIT          958 non-null    object
#  13  ENG_CNSM_BU       958 non-null    object
#  14  ENG_CNSM_BU_UNIT  958 non-null    object
#  15  VRFCT_AGNCY       958 non-null    object
#  16  TST               958 non-null    object
# dtypes: int64(2), object(15)
# memory usage: 127.4+ KB

# %%
df['DSGN_INDS'].unique()
# Out:
# array(['석유화학', '교통(여객)', '철강', '음료제조업', '음식료품', '조선', '건물', '광업', '섬유',
#        '반도체.디스플레이.전기전자', '폐기물', '유리', '교통(해운)', '자동차', '교통(화물)',
#        '식료품 제조업', '비철금속', '제지', '유리 · 요업', '건설', '기계', '시멘트', '전기전자',
#        '집단에너지', '요업', '산업단지', '지정외 폐기물처리업', '반도체', '발전 · 에너지', '통신', '항공',
#        '발전에너지', '목재', '정유', '교통(철도)', '하수처리업', '수도', '디스플레이',
#        '지정외 폐기물처리업 등', '하수, 폐수 및 분뇨 처리업'], dtype=object)

# %%
df['DSGN_INDS'].value_counts()
# Out:
# 석유화학               132
# 건물                  86
# 철강                  73
# 폐기물                 69
# 자동차                 61
# 비철금속                47
# 제지                  44
# 기계                  36
# 교통(여객)              34
# 시멘트                 30
# 음식료품                29
# 섬유                  27
# 전기전자                24
# 반도체.디스플레이.전기전자      24
# 반도체                 23
# 유리                  20
# 집단에너지               18
# 발전 · 에너지            18
# 유리 · 요업             14
# 조선                  14
# 산업단지                13
# 통신                  12
# 식료품 제조업             12
# 교통(화물)              11
# 교통(철도)              10
# 교통(해운)              10
# 발전에너지                9
# 목재                   7
# 항공                   7
# 광업                   6
# 요업                   6
# 정유                   6
# 음료제조업                6
# 지정외 폐기물처리업           5
# 건설                   4
# 수도                   3
# 하수처리업                3
# 디스플레이                3
# 지정외 폐기물처리업 등         1
# 하수, 폐수 및 분뇨 처리업      1
# Name: DSGN_INDS, dtype: int64

# %%
# 교통 통합
df.loc[df['DSGN_INDS'] == '교통(여객)', 'DSGN_INDS'] = '교통'
df.loc[df['DSGN_INDS'] == '교통(화물)', 'DSGN_INDS'] = '교통'
df.loc[df['DSGN_INDS'] == '교통(철도)', 'DSGN_INDS'] = '교통'
df.loc[df['DSGN_INDS'] == '교통(해운)', 'DSGN_INDS'] = '교통'
df.loc[df['DSGN_INDS'] == '항공', 'DSGN_INDS'] = '교통'

# 반도체.디스플레이.전기전자 통합
df.loc[df['DSGN_INDS'] == '반도체', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '전기전자', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '디스플레이', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '통신', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '기계', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '자동차', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'

# 유리 · 요업 통합
df.loc[df['DSGN_INDS'] == '유리', 'DSGN_INDS'] = '유리 · 요업'
df.loc[df['DSGN_INDS'] == '요업', 'DSGN_INDS'] = '유리 · 요업'
df.loc[df['DSGN_INDS'] == '시멘트', 'DSGN_INDS'] = '유리 · 요업'

# 발전 · 에너지 통합
df.loc[df['DSGN_INDS'] == '발전에너지', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '집단에너지', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '수도', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '지정외 폐기물처리업', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '하수처리업', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '지정외 폐기물처리업 등', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '하수, 폐수 및 분뇨 처리업', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '폐기물', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '처리업', 'DSGN_INDS'] = '발전 · 에너지'

# 광업 통합
df.loc[df['DSGN_INDS'] == '철강', 'DSGN_INDS'] = '광업'

# 건물 통합
df.loc[df['DSGN_INDS'] == '건설', 'DSGN_INDS'] = '건물'
df.loc[df['DSGN_INDS'] == '산업단지', 'DSGN_INDS'] = '건물'

# 음식료품 · 제조업 통합
df.loc[df['DSGN_INDS'] == '음료제조업', 'DSGN_INDS'] = '음식료품 · 제조업'
df.loc[df['DSGN_INDS'] == '식료품 제조업', 'DSGN_INDS'] = '음식료품 · 제조업'
df.loc[df['DSGN_INDS'] == '음식료품', 'DSGN_INDS'] = '음식료품 · 제조업'

# 석유화학 통합
df.loc[df['DSGN_INDS'] == '정유', 'DSGN_INDS'] = '석유화학'
df.loc[df['DSGN_INDS'] == '섬유', 'DSGN_INDS'] = '석유화학'

# 조선 통합
df.loc[df['DSGN_INDS'] == '목재', 'DSGN_INDS'] = '조선'
df.loc[df['DSGN_INDS'] == '비철금속', 'DSGN_INDS'] = '조선'

# %%
df['DSGN_INDS'].unique()
# Out:
# array(['석유화학', '교통', '광업', '음식료품 · 제조업', '조선', '건물', '반도체.디스플레이.전기전자',
#        '발전 · 에너지', '유리 · 요업', '제지'], dtype=object)

# %%
df['DSGN_INDS'].value_counts()
# Out:
# 반도체.디스플레이.전기전자    183
# 석유화학              165
# 발전 · 에너지          127
# 건물                103
# 광업                 79
# 교통                 72
# 유리 · 요업            70
# 조선                 68
# 음식료품 · 제조업         47
# 제지                 44
# Name: DSGN_INDS, dtype: int64

# %%
df.head(10)
# Out:
#    NO DPRTM_CHRG  ...          VRFCT_AGNCY              TST
# 0   1    산업통상자원부  ...            (재)한국품질재단                -
# 1   2      국토교통부  ...           (주)한국경영인증원                -
# 2   3    산업통상자원부  ...               한국표준협회                -
# 3   4    농림축산식품부  ...       (재)한국화학융합시험연구원                -
# 4   5    농림축산식품부  ...            한국산업기술시험원                -
# 5   6    산업통상자원부  ...               한국표준협회  229,245,382,265
# 6   7    산업통상자원부  ...  ㈜디엔브이지엘비즈니스어슈어런스코리아                -
# 7   8      국토교통부  ...               한국표준협회                -
# 8   9    산업통상자원부  ...               한국표준협회                -
# 9  10      국토교통부  ...              산림조합중앙회  286,641,971,000
#
# [10 rows x 17 columns]

# %%
df.to_excel('industry_combine_2017.xlsx',index=False)
