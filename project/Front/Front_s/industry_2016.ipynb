# %%
import pandas as pd

# %%
df = pd.read_csv('사업장별_온실가스_배출량∙에너지_사용량_(2016).CSV')
df.head(5)
# Out:
#    NO DPRTM_CHRG  ...     VRFCT_AGNCY              TST
# 0   1    산업통상자원부  ...       (재)한국품질재단                -
# 1   2    농림축산식품부  ...  (재)한국화학융합시험연구원                -
# 2   3    농림축산식품부  ...      대일이엔씨기술(주)                -
# 3   4    산업통상자원부  ...          안진회계법인  137,543,470,935
# 4   5    산업통상자원부  ...   한국생산성본부인증원(주)                -
#
# [5 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 898 entries, 0 to 897
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NO                898 non-null    int64
#  1   DPRTM_CHRG        898 non-null    object
#  2   CORP_NM           898 non-null    object
#  3   ADDRESS           898 non-null    object
#  4   TRGT_YEAR         898 non-null    int64
#  5   DSGN_CLSF         898 non-null    object
#  6   DSGN_INDS         898 non-null    object
#  7   GHG_EMS           898 non-null    object
#  8   GHG_UNIT          898 non-null    object
#  9   GHG_EMS_BU        898 non-null    object
#  10  GHG_EMS_BU_UNIT   898 non-null    object
#  11  ENG_CNSM          898 non-null    object
#  12  ENG_UNIT          898 non-null    object
#  13  ENG_CNSM_BU       898 non-null    object
#  14  ENG_CNSM_BU_UNIT  898 non-null    object
#  15  VRFCT_AGNCY       898 non-null    object
#  16  TST               898 non-null    object
# dtypes: int64(2), object(15)
# memory usage: 119.4+ KB

# %%
df['DSGN_INDS'].unique()
# Out:
# array(['석유화학', '음식료품', '철강', '조선', '건물', '교통(여객)', '광업', '섬유',
#        '반도체.디스플레이.전기전자', '폐기물', '유리', '교통(화물)', '비철금속', '제지', '요업', '건설',
#        '시멘트', '반도체', '자동차', '기계', '전기전자', '집단에너지', '유리 · 요업', '산업단지',
#        '발전에너지', '통신', '항공', '목재', '정유', '교통(철도)', '수도', '디스플레이', '교통(해운)',
#        '발전 · 에너지'], dtype=object)

# %%
df['DSGN_INDS'].value_counts()
# Out:
# 석유화학              124
# 건물                 84
# 폐기물                76
# 철강                 71
# 자동차                58
# 음식료품               47
# 제지                 45
# 비철금속               39
# 기계                 33
# 시멘트                29
# 섬유                 27
# 전기전자               25
# 반도체.디스플레이.전기전자     23
# 반도체                23
# 유리                 21
# 교통(여객)             20
# 집단에너지              18
# 발전 · 에너지           15
# 조선                 14
# 산업단지               13
# 유리 · 요업            11
# 통신                 11
# 교통(화물)             10
# 교통(철도)             10
# 목재                  7
# 항공                  7
# 발전에너지               6
# 광업                  6
# 요업                  6
# 디스플레이               5
# 정유                  5
# 건설                  4
# 수도                  3
# 교통(해운)              2
# Name: DSGN_INDS, dtype: int64

# %%
# 교통 통합
df.loc[df['DSGN_INDS'] == '교통(여객)', 'DSGN_INDS'] = '교통'
df.loc[df['DSGN_INDS'] == '교통(화물)', 'DSGN_INDS'] = '교통'
df.loc[df['DSGN_INDS'] == '교통(철도)', 'DSGN_INDS'] = '교통'
df.loc[df['DSGN_INDS'] == '교통(해운)', 'DSGN_INDS'] = '교통'
df.loc[df['DSGN_INDS'] == '항공', 'DSGN_INDS'] = '교통'

# 반도체.디스플레이.전기전자 통합
df.loc[df['DSGN_INDS'] == '반도체', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '전기전자', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '디스플레이', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '기계', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '자동차', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '통신', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'

# 유리 · 요업 통합
df.loc[df['DSGN_INDS'] == '유리', 'DSGN_INDS'] = '유리 · 요업'
df.loc[df['DSGN_INDS'] == '요업', 'DSGN_INDS'] = '유리 · 요업'
df.loc[df['DSGN_INDS'] == '시멘트', 'DSGN_INDS'] = '유리 · 요업'

# 발전 · 에너지 통합
df.loc[df['DSGN_INDS'] == '발전에너지', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '집단에너지', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '수도', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '폐기물', 'DSGN_INDS'] = '발전 · 에너지'

# 광업 통합
df.loc[df['DSGN_INDS'] == '철강', 'DSGN_INDS'] = '광업'

# 건물 통합
df.loc[df['DSGN_INDS'] == '건설', 'DSGN_INDS'] = '건물'
df.loc[df['DSGN_INDS'] == '산업단지', 'DSGN_INDS'] = '건물'

# 석유화학 통합
df.loc[df['DSGN_INDS'] == '정유', 'DSGN_INDS'] = '석유화학'
df.loc[df['DSGN_INDS'] == '섬유', 'DSGN_INDS'] = '석유화학'

# 조선 통합
df.loc[df['DSGN_INDS'] == '목재', 'DSGN_INDS'] = '조선'
df.loc[df['DSGN_INDS'] == '비철금속', 'DSGN_INDS'] = '조선'

# %%
df['DSGN_INDS'].unique()
# Out:
# array(['석유화학', '음식료품', '광업', '조선', '건물', '교통', '반도체.디스플레이.전기전자',
#        '발전 · 에너지', '유리 · 요업', '제지'], dtype=object)

# %%
df['DSGN_INDS'].value_counts()
# Out:
# 반도체.디스플레이.전기전자    178
# 석유화학              156
# 발전 · 에너지          118
# 건물                101
# 광업                 77
# 유리 · 요업            67
# 조선                 60
# 교통                 49
# 음식료품               47
# 제지                 45
# Name: DSGN_INDS, dtype: int64

# %%
df.head(10)
# Out:
#    NO DPRTM_CHRG  ...     VRFCT_AGNCY              TST
# 0   1    산업통상자원부  ...       (재)한국품질재단                -
# 1   2    농림축산식품부  ...  (재)한국화학융합시험연구원                -
# 2   3    농림축산식품부  ...      대일이엔씨기술(주)                -
# 3   4    산업통상자원부  ...          안진회계법인  137,543,470,935
# 4   5    산업통상자원부  ...   한국생산성본부인증원(주)                -
# 5   6      국토교통부  ...         산림조합중앙회                -
# 6   7      국토교통부  ...          한국표준협회                -
# 7   8    산업통상자원부  ...          한국표준협회                -
# 8   9      국토교통부  ...      (주)한국경영인증원  294,323,186,000
# 9  10      국토교통부  ...      (주)한국경영인증원  109,967,005,000
#
# [10 rows x 17 columns]

# %%
df.to_excel('industry_combine_2016.xlsx',index=False)
