# %%
import pandas as pd

# %%
df = pd.read_csv('사업장별_온실가스_배출량∙에너지_사용량_(2020).CSV')
df.head(5)
# Out:
#    NO DPRTM_CHRG   CORP_NM  ... ENG_CNSM_BU_UNIT  VRFCT_AGNCY                 TST
# 0   1      국토교통부   (유)호남고속  ...                -   (주)한국경영인증원                   -
# 1   2      국토교통부   (주)경기고속  ...            TJ/억원      산림조합중앙회     182,683,071,861
# 2   3      국토교통부   (주)경남고속  ...                -   (주)한국경영인증원                   -
# 3   4      국토교통부  (주)공항리무진  ...                -   (주)한국경영인증원                   -
# 4   5      국토교통부   (주)국민은행  ...            TJ/억원       한국표준협회  23,470,113,000,000
#
# [5 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NO                1061 non-null   int64
#  1   DPRTM_CHRG        1061 non-null   object
#  2   CORP_NM           1061 non-null   object
#  3   ADDRESS           1061 non-null   object
#  4   TRGT_YEAR         1061 non-null   int64
#  5   DSGN_CLSF         1061 non-null   object
#  6   DSGN_INDS         1061 non-null   object
#  7   GHG_EMS           1061 non-null   object
#  8   GHG_UNIT          1061 non-null   object
#  9   GHG_EMS_BU        1061 non-null   object
#  10  GHG_EMS_BU_UNIT   1061 non-null   object
#  11  ENG_CNSM          1061 non-null   object
#  12  ENG_UNIT          1061 non-null   object
#  13  ENG_CNSM_BU       1061 non-null   object
#  14  ENG_CNSM_BU_UNIT  1061 non-null   object
#  15  VRFCT_AGNCY       1061 non-null   object
#  16  TST               1061 non-null   object
# dtypes: int64(2), object(15)
# memory usage: 141.0+ KB

# %%
df['DSGN_INDS'].unique()
# Out:
# array(['교통(여객)', '건물', '교통(화물)', '건설', '수송', '교통(철도)', '산업', '음료제조업',
#        '식료품 제조업', '담배제조업', '기계', '섬유', '석유화학', '전기전자', '자동차', '요업', '유리',
#        '철강', '비철금속', '반도체', '집단에너지', '시멘트', '유리 · 요업', '반도체.디스플레이.전기전자',
#        '광업', '통신', '조선', '제지', '발전에너지', '산업단지', '교통(해운)', '폐기물', '전환',
#        '지정외 폐기물처리업', '지정외 폐기물처리업 등', '공공기타', '하수처리업'], dtype=object)

# %%
df['DSGN_INDS'].value_counts()
# Out:
# 산업                467
# 건물                 97
# 폐기물                77
# 교통(여객)             52
# 전환                 50
# 석유화학               41
# 자동차                28
# 기계                 24
# 철강                 23
# 전기전자               23
# 교통(화물)             21
# 비철금속               18
# 식료품 제조업            16
# 섬유                 12
# 수송                 11
# 교통(해운)             10
# 교통(철도)             10
# 음료제조업               8
# 지정외 폐기물처리업          8
# 반도체                 7
# 지정외 폐기물처리업 등        6
# 유리                  6
# 시멘트                 6
# 발전에너지               5
# 반도체.디스플레이.전기전자      4
# 조선                  4
# 집단에너지               4
# 요업                  3
# 건설                  3
# 통신                  3
# 산업단지                3
# 하수처리업               2
# 유리 · 요업             2
# 광업                  2
# 공공기타                2
# 제지                  2
# 담배제조업               1
# Name: DSGN_INDS, dtype: int64

# %%
# 교통 통합
df.loc[df['DSGN_INDS'] == '교통(여객)', 'DSGN_INDS'] = '교통'
df.loc[df['DSGN_INDS'] == '교통(화물)', 'DSGN_INDS'] = '교통'
df.loc[df['DSGN_INDS'] == '교통(철도)', 'DSGN_INDS'] = '교통'
df.loc[df['DSGN_INDS'] == '교통(해운)', 'DSGN_INDS'] = '교통'
df.loc[df['DSGN_INDS'] == '수송', 'DSGN_INDS'] = '교통'

# 반도체.디스플레이.전기전자 통합
df.loc[df['DSGN_INDS'] == '반도체', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '전기전자', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '통신', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '기계', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'
df.loc[df['DSGN_INDS'] == '자동차', 'DSGN_INDS'] = '반도체.디스플레이.전기전자'

# 유리 · 요업 통합
df.loc[df['DSGN_INDS'] == '유리', 'DSGN_INDS'] = '유리 · 요업'
df.loc[df['DSGN_INDS'] == '요업', 'DSGN_INDS'] = '유리 · 요업'
df.loc[df['DSGN_INDS'] == '시멘트', 'DSGN_INDS'] = '유리 · 요업'

# 발전 · 에너지 통합
df.loc[df['DSGN_INDS'] == '발전에너지', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '집단에너지', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '공공기타', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '지정외 폐기물처리업', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '하수처리업', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '지정외 폐기물처리업 등', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '폐기물', 'DSGN_INDS'] = '발전 · 에너지'
df.loc[df['DSGN_INDS'] == '전환', 'DSGN_INDS'] = '발전 · 에너지'

# 음식료품 · 제조업 통합
df.loc[df['DSGN_INDS'] == '음료제조업', 'DSGN_INDS'] = '음식료품 · 제조업'
df.loc[df['DSGN_INDS'] == '식료품 제조업', 'DSGN_INDS'] = '음식료품 · 제조업'
df.loc[df['DSGN_INDS'] == '담배제조업', 'DSGN_INDS'] = '음식료품 · 제조업'

# 건물 통합
df.loc[df['DSGN_INDS'] == '건설', 'DSGN_INDS'] = '건물'
df.loc[df['DSGN_INDS'] == '산업단지', 'DSGN_INDS'] = '건물'
df.loc[df['DSGN_INDS'] == '산업', 'DSGN_INDS'] = '건물'

# 석유화학 통합
df.loc[df['DSGN_INDS'] == '섬유', 'DSGN_INDS'] = '석유화학'

# 조선 통합
df.loc[df['DSGN_INDS'] == '비철금속', 'DSGN_INDS'] = '조선'

# 광업 통합
df.loc[df['DSGN_INDS'] == '철강', 'DSGN_INDS'] = '광업'

# %%
df['DSGN_INDS'].unique()
# Out:
# array(['교통', '건물', '음식료품 · 제조업', '반도체.디스플레이.전기전자', '석유화학', '유리 · 요업',
#        '광업', '조선', '발전 · 에너지', '제지'], dtype=object)

# %%
df['DSGN_INDS'].value_counts()
# Out:
# 건물                570
# 발전 · 에너지          154
# 교통                104
# 반도체.디스플레이.전기전자     89
# 석유화학               53
# 광업                 25
# 음식료품 · 제조업         25
# 조선                 22
# 유리 · 요업            17
# 제지                  2
# Name: DSGN_INDS, dtype: int64

# %%
df.head(10)
# Out:
#    NO DPRTM_CHRG    CORP_NM  ... ENG_CNSM_BU_UNIT    VRFCT_AGNCY                 TST
# 0   1      국토교통부    (유)호남고속  ...                -     (주)한국경영인증원                   -
# 1   2      국토교통부    (주)경기고속  ...            TJ/억원        산림조합중앙회     182,683,071,861
# 2   3      국토교통부    (주)경남고속  ...                -     (주)한국경영인증원                   -
# 3   4      국토교통부   (주)공항리무진  ...                -     (주)한국경영인증원                   -
# 4   5      국토교통부    (주)국민은행  ...            TJ/억원         한국표준협회  23,470,113,000,000
# 5   6      국토교통부    (주)금남고속  ...                -     (주)한국경영인증원                   -
# 6   7      국토교통부    (주)농협물류  ...                -         한국표준협회                   -
# 7   8      국토교통부  (주)대명티피앤이  ...                -     (주)한국경영인증원                   -
# 8   9      국토교통부    (주)대우건설  ...            TJ/억원  (주)비에스아이그룹코리아   7,637,255,920,891
# 9  10      국토교통부    (주)대원고속  ...            TJ/억원        산림조합중앙회     187,309,722,609
#
# [10 rows x 17 columns]

# %%
df.to_excel('industry_combine_2020.xlsx',index=False)
