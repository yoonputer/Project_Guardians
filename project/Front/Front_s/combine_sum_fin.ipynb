# %%
import pandas as pd

# %%
df1 = pd.read_csv('industry_combine_2016.csv')
df2 = pd.read_csv('industry_combine_2017.csv')
df3 = pd.read_csv('industry_combine_2018.csv')
df4 = pd.read_csv('industry_combine_2019.csv')
df5 = pd.read_csv('industry_combine_2020.csv')

# %%
df_sum = pd.concat([df1,df2,df3,df4,df5],axis=0)

# %%
df_sum
# Out:
#         NO DPRTM_CHRG  ...     VRFCT_AGNCY                TST
# 0        1    산업통상자원부  ...       (재)한국품질재단                  -
# 1        2    농림축산식품부  ...  (재)한국화학융합시험연구원                  -
# 2        3    농림축산식품부  ...      대일이엔씨기술(주)                  -
# 3        4    산업통상자원부  ...          안진회계법인    137,543,470,935
# 4        5    산업통상자원부  ...   한국생산성본부인증원(주)                  -
# ...    ...        ...  ...             ...                ...
# 1056  1057        환경부  ...       (재)한국품질재단    722,533,748,065
# 1057  1058        환경부  ...       (재)한국품질재단  3,143,280,085,567
# 1058  1059        환경부  ...       (재)한국품질재단  1,643,261,559,101
# 1059  1060        환경부  ...          한국표준협회    733,457,960,859
# 1060  1061        환경부  ...        ㈜한국품질보증원                  -
#
# [4963 rows x 17 columns]

# %%
df_sum.to_excel('combine_fin.xlsx',index=False)
